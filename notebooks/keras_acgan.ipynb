# %%
# -*- coding: utf-8 -*-
"""
Train an Auxiliary Classifier Generative Adversarial Network (ACGAN) on the
MNIST dataset. See https://arxiv.org/abs/1610.09585 for more details.

You should start to see reasonable images after ~5 epochs, and good images
by ~15 epochs. You should use a GPU, as the convolution-heavy operations are
very slow on the CPU. Prefer the TensorFlow backend if you plan on iterating,
as the compilation time can be a blocker using Theano.

Timings:

Hardware           | Backend | Time / Epoch
-------------------------------------------
 CPU               | TF      | 3 hrs
 Titan X (maxwell) | TF      | 4 min
 Titan X (maxwell) | TH      | 7 min

Consult https://github.com/lukedeo/keras-acgan for more information and
example output
"""
from __future__ import print_function

from collections import defaultdict
try:
    import cPickle as pickle
except ImportError:
    import pickle
from PIL import Image

from six.moves import range

from keras.datasets import mnist
from keras import layers
from keras.layers import Input, Dense, Reshape, Flatten, Embedding, Dropout
from keras.layers import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2DTranspose, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.utils.generic_utils import Progbar
import numpy as np

np.random.seed(1337)
num_classes = 10


def build_generator(latent_size):
    # we will map a pair of (z, L), where z is a latent vector and L is a
    # label drawn from P_c, to image space (..., 28, 28, 1)
    cnn = Sequential()

    cnn.add(Dense(3 * 3 * 384, input_dim=latent_size, activation='relu'))
    cnn.add(Reshape((3, 3, 384)))

    # upsample to (7, 7, ...)
    cnn.add(Conv2DTranspose(192, 5, strides=1, padding='valid',
                            activation='relu',
                            kernel_initializer='glorot_normal'))
    cnn.add(BatchNormalization())

    # upsample to (14, 14, ...)
    cnn.add(Conv2DTranspose(96, 5, strides=2, padding='same',
                            activation='relu',
                            kernel_initializer='glorot_normal'))
    cnn.add(BatchNormalization())

    # upsample to (28, 28, ...)
    cnn.add(Conv2DTranspose(1, 5, strides=2, padding='same',
                            activation='tanh',
                            kernel_initializer='glorot_normal'))

    # this is the z space commonly referred to in GAN papers
    latent = Input(shape=(latent_size, ))

    # this will be our label
    image_class = Input(shape=(1,), dtype='int32')

    cls = Flatten()(Embedding(num_classes, latent_size,
                              embeddings_initializer='glorot_normal')(image_class))

    # hadamard product between z-space and a class conditional embedding
    h = layers.multiply([latent, cls])

    fake_image = cnn(h)

    return Model([latent, image_class], fake_image)


def build_discriminator():
    # build a relatively standard conv net, with LeakyReLUs as suggested in
    # the reference paper
    cnn = Sequential()

    cnn.add(Conv2D(32, 3, padding='same', strides=2,
                   input_shape=(28, 28, 1)))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Conv2D(64, 3, padding='same', strides=1))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Conv2D(128, 3, padding='same', strides=2))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Conv2D(256, 3, padding='same', strides=1))
    cnn.add(LeakyReLU(0.2))
    cnn.add(Dropout(0.3))

    cnn.add(Flatten())

    image = Input(shape=(28, 28, 1))

    features = cnn(image)

    # first output (name=generation) is whether or not the discriminator
    # thinks the image that is being shown is fake, and the second output
    # (name=auxiliary) is the class that the discriminator thinks the image
    # belongs to.
    fake = Dense(1, activation='sigmoid', name='generation')(features)
    aux = Dense(num_classes, activation='softmax', name='auxiliary')(features)

    return Model(image, [fake, aux])

if __name__ == '__main__':

    # batch and latent size taken from the paper
    epochs = 100
    batch_size = 100
    latent_size = 100

    # Adam parameters suggested in https://arxiv.org/abs/1511.06434
    adam_lr = 0.0002
    adam_beta_1 = 0.5

    # build the discriminator
    print('Discriminator model:')
    discriminator = build_discriminator()
    discriminator.compile(
        optimizer=Adam(lr=adam_lr, beta_1=adam_beta_1),
        loss=['binary_crossentropy', 'sparse_categorical_crossentropy']
    )
    discriminator.summary()

    # build the generator
    generator = build_generator(latent_size)

    latent = Input(shape=(latent_size, ))
    image_class = Input(shape=(1,), dtype='int32')

    # get a fake image
    fake = generator([latent, image_class])

    # we only want to be able to train generation for the combined model
    discriminator.trainable = False
    fake, aux = discriminator(fake)
    combined = Model([latent, image_class], [fake, aux])

    print('Combined model:')
    combined.compile(
        optimizer=Adam(lr=adam_lr, beta_1=adam_beta_1),
        loss=['binary_crossentropy', 'sparse_categorical_crossentropy']
    )
    combined.summary()

    # get our mnist data, and force it to be of shape (..., 28, 28, 1) with
    # range [-1, 1]
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = (x_train.astype(np.float32) - 127.5) / 127.5
    x_train = np.expand_dims(x_train, axis=-1)

    x_test = (x_test.astype(np.float32) - 127.5) / 127.5
    x_test = np.expand_dims(x_test, axis=-1)

    num_train, num_test = x_train.shape[0], x_test.shape[0]

    train_history = defaultdict(list)
    test_history = defaultdict(list)

    for epoch in range(1, epochs + 1):
        print('Epoch {}/{}'.format(epoch, epochs))

        num_batches = int(x_train.shape[0] / batch_size)
        progress_bar = Progbar(target=num_batches)

        # we don't want the discriminator to also maximize the classification
        # accuracy of the auxiliary classifier on generated images, so we
        # don't train discriminator to produce class labels for generated
        # images (see https://openreview.net/forum?id=rJXTf9Bxg).
        # To preserve sum of sample weights for the auxiliary classifier,
        # we assign sample weight of 2 to the real images.
        disc_sample_weight = [np.ones(2 * batch_size),
                              np.concatenate((np.ones(batch_size) * 2,
                                              np.zeros(batch_size)))]

        epoch_gen_loss = []
        epoch_disc_loss = []

        for index in range(num_batches):
            # generate a new batch of noise
            noise = np.random.uniform(-1, 1, (batch_size, latent_size))

            # get a batch of real images
            image_batch = x_train[index * batch_size:(index + 1) * batch_size]
            label_batch = y_train[index * batch_size:(index + 1) * batch_size]

            # sample some labels from p_c
            sampled_labels = np.random.randint(0, num_classes, batch_size)

            # generate a batch of fake images, using the generated labels as a
            # conditioner. We reshape the sampled labels to be
            # (batch_size, 1) so that we can feed them into the embedding
            # layer as a length one sequence
            generated_images = generator.predict(
                [noise, sampled_labels.reshape((-1, 1))], verbose=0)

            x = np.concatenate((image_batch, generated_images))

            # use one-sided soft real/fake labels
            # Salimans et al., 2016
            # https://arxiv.org/pdf/1606.03498.pdf (Section 3.4)
            soft_zero, soft_one = 0, 0.95
            y = np.array([soft_one] * batch_size + [soft_zero] * batch_size)
            aux_y = np.concatenate((label_batch, sampled_labels), axis=0)

            # see if the discriminator can figure itself out...
            epoch_disc_loss.append(discriminator.train_on_batch(
                x, [y, aux_y], sample_weight=disc_sample_weight))

            # make new noise. we generate 2 * batch size here such that we have
            # the generator optimize over an identical number of images as the
            # discriminator
            noise = np.random.uniform(-1, 1, (2 * batch_size, latent_size))
            sampled_labels = np.random.randint(0, num_classes, 2 * batch_size)

            # we want to train the generator to trick the discriminator
            # For the generator, we want all the {fake, not-fake} labels to say
            # not-fake
            trick = np.ones(2 * batch_size) * soft_one

            epoch_gen_loss.append(combined.train_on_batch(
                [noise, sampled_labels.reshape((-1, 1))],
                [trick, sampled_labels]))

            progress_bar.update(index + 1)

        print('Testing for epoch {}:'.format(epoch))

        # evaluate the testing loss here

        # generate a new batch of noise
        noise = np.random.uniform(-1, 1, (num_test, latent_size))

        # sample some labels from p_c and generate images from them
        sampled_labels = np.random.randint(0, num_classes, num_test)
        generated_images = generator.predict(
            [noise, sampled_labels.reshape((-1, 1))], verbose=False)

        x = np.concatenate((x_test, generated_images))
        y = np.array([1] * num_test + [0] * num_test)
        aux_y = np.concatenate((y_test, sampled_labels), axis=0)

        # see if the discriminator can figure itself out...
        discriminator_test_loss = discriminator.evaluate(
            x, [y, aux_y], verbose=False)

        discriminator_train_loss = np.mean(np.array(epoch_disc_loss), axis=0)

        # make new noise
        noise = np.random.uniform(-1, 1, (2 * num_test, latent_size))
        sampled_labels = np.random.randint(0, num_classes, 2 * num_test)

        trick = np.ones(2 * num_test)

        generator_test_loss = combined.evaluate(
            [noise, sampled_labels.reshape((-1, 1))],
            [trick, sampled_labels], verbose=False)

        generator_train_loss = np.mean(np.array(epoch_gen_loss), axis=0)

        # generate an epoch report on performance
        train_history['generator'].append(generator_train_loss)
        train_history['discriminator'].append(discriminator_train_loss)

        test_history['generator'].append(generator_test_loss)
        test_history['discriminator'].append(discriminator_test_loss)

        print('{0:<22s} | {1:4s} | {2:15s} | {3:5s}'.format(
            'component', *discriminator.metrics_names))
        print('-' * 65)

        ROW_FMT = '{0:<22s} | {1:<4.2f} | {2:<15.4f} | {3:<5.4f}'
        print(ROW_FMT.format('generator (train)',
                             *train_history['generator'][-1]))
        print(ROW_FMT.format('generator (test)',
                             *test_history['generator'][-1]))
        print(ROW_FMT.format('discriminator (train)',
                             *train_history['discriminator'][-1]))
        print(ROW_FMT.format('discriminator (test)',
                             *test_history['discriminator'][-1]))

        # save weights every epoch
        generator.save_weights(
            'params_generator_epoch_{0:03d}.hdf5'.format(epoch), True)
        discriminator.save_weights(
            'params_discriminator_epoch_{0:03d}.hdf5'.format(epoch), True)

        # generate some digits to display
        num_rows = 40
        noise = np.tile(np.random.uniform(-1, 1, (num_rows, latent_size)),
                        (num_classes, 1))

        sampled_labels = np.array([
            [i] * num_rows for i in range(num_classes)
        ]).reshape(-1, 1)

        # get a batch to display
        generated_images = generator.predict(
            [noise, sampled_labels], verbose=0)

        # prepare real images sorted by class label
        real_labels = y_train[(epoch - 1) * num_rows * num_classes:
                              epoch * num_rows * num_classes]
        indices = np.argsort(real_labels, axis=0)
        real_images = x_train[(epoch - 1) * num_rows * num_classes:
                              epoch * num_rows * num_classes][indices]

        # display generated images, white separator, real images
        img = np.concatenate(
            (generated_images,
             np.repeat(np.ones_like(x_train[:1]), num_rows, axis=0),
             real_images))

        # arrange them into a grid
        img = (np.concatenate([r.reshape(-1, 28)
                               for r in np.split(img, 2 * num_classes + 1)
                               ], axis=-1) * 127.5 + 127.5).astype(np.uint8)

        Image.fromarray(img).save(
            'plot_epoch_{0:03d}_generated.png'.format(epoch))

    with open('acgan-history.pkl', 'wb') as f:
        pickle.dump({'train': train_history, 'test': test_history}, f)
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Discriminator model:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 12544)        387840      input_1[0][0]
# __________________________________________________________________________________________________
# generation (Dense)              (None, 1)            12545       sequential_1[1][0]
# __________________________________________________________________________________________________
# auxiliary (Dense)               (None, 10)           125450      sequential_1[1][0]
# ==================================================================================================
# Total params: 525,835
# Trainable params: 525,835
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Combined model:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 28, 28, 1)    2657897     input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 [(None, 1), (None, 1 525835      model_2[1][0]
# ==================================================================================================
# Total params: 3,183,732
# Trainable params: 2,657,321
# Non-trainable params: 526,411
# __________________________________________________________________________________________________
# Epoch 1/100
# /usr/local/lib/python3.6/dist-packages/Keras-2.1.4-py3.6.egg/keras/engine/training.py:973: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# 600/600 [==============================] - 102s 171ms/step
# Testing for epoch 1:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 1.39 | 0.9729          | 0.4180
# generator (test)       | 0.94 | 0.9284          | 0.0147
# discriminator (train)  | 1.53 | 0.6938          | 0.8404
# discriminator (test)   | 0.73 | 0.6346          | 0.0908
# Epoch 2/100
# 600/600 [==============================] - 99s 165ms/step
# Testing for epoch 2:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.94 | 0.9193          | 0.0249
# generator (test)       | 0.70 | 0.6896          | 0.0125
# discriminator (train)  | 1.00 | 0.6934          | 0.3045
# discriminator (test)   | 0.76 | 0.7139          | 0.0485
# Epoch 3/100
# 600/600 [==============================] - 97s 161ms/step
# Testing for epoch 3:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.84 | 0.8287          | 0.0154
# generator (test)       | 0.73 | 0.7240          | 0.0025
# discriminator (train)  | 0.91 | 0.7081          | 0.2051
# discriminator (test)   | 0.76 | 0.7278          | 0.0324
# Epoch 4/100
# 600/600 [==============================] - 96s 161ms/step
# Testing for epoch 4:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.82 | 0.8128          | 0.0110
# generator (test)       | 0.72 | 0.7168          | 0.0010
# discriminator (train)  | 0.88 | 0.7099          | 0.1659
# discriminator (test)   | 0.74 | 0.7129          | 0.0255
# Epoch 5/100
# 600/600 [==============================] - 96s 160ms/step
# Testing for epoch 5:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.80 | 0.7945          | 0.0068
# generator (test)       | 0.75 | 0.7481          | 0.0006
# discriminator (train)  | 0.85 | 0.7084          | 0.1424
# discriminator (test)   | 0.73 | 0.7074          | 0.0219
# Epoch 6/100
# 600/600 [==============================] - 94s 157ms/step
# Testing for epoch 6:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.80 | 0.7908          | 0.0061
# generator (test)       | 0.74 | 0.7390          | 0.0005
# discriminator (train)  | 0.83 | 0.7071          | 0.1256
# discriminator (test)   | 0.76 | 0.7364          | 0.0201
# Epoch 7/100
# 600/600 [==============================] - 94s 157ms/step
# Testing for epoch 7:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.79 | 0.7840          | 0.0058
# generator (test)       | 0.76 | 0.7613          | 0.0008
# discriminator (train)  | 0.82 | 0.7059          | 0.1109
# discriminator (test)   | 0.76 | 0.7402          | 0.0191
# Epoch 8/100
# 600/600 [==============================] - 94s 156ms/step
# Testing for epoch 8:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.79 | 0.7819          | 0.0051
# generator (test)       | 0.74 | 0.7425          | 0.0013
# discriminator (train)  | 0.81 | 0.7061          | 0.1017
# discriminator (test)   | 0.73 | 0.7089          | 0.0178
# Epoch 9/100
# 600/600 [==============================] - 94s 156ms/step
# Testing for epoch 9:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7779          | 0.0041
# generator (test)       | 0.77 | 0.7666          | 0.0005
# discriminator (train)  | 0.80 | 0.7045          | 0.0952
# discriminator (test)   | 0.74 | 0.7229          | 0.0165
# Epoch 10/100
# 600/600 [==============================] - 93s 156ms/step
# Testing for epoch 10:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7774          | 0.0042
# generator (test)       | 0.75 | 0.7499          | 0.0003
# discriminator (train)  | 0.79 | 0.7029          | 0.0859
# discriminator (test)   | 0.72 | 0.7086          | 0.0149
# Epoch 11/100
# 600/600 [==============================] - 93s 156ms/step
# Testing for epoch 11:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7748          | 0.0042
# generator (test)       | 0.78 | 0.7828          | 0.0004
# discriminator (train)  | 0.78 | 0.7026          | 0.0817
# discriminator (test)   | 0.72 | 0.7089          | 0.0147
# Epoch 12/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 12:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7731          | 0.0036
# generator (test)       | 0.77 | 0.7655          | 0.0004
# discriminator (train)  | 0.78 | 0.7020          | 0.0753
# discriminator (test)   | 0.72 | 0.7097          | 0.0140
# Epoch 13/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 13:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7726          | 0.0037
# generator (test)       | 0.78 | 0.7779          | 0.0007
# discriminator (train)  | 0.77 | 0.7011          | 0.0710
# discriminator (test)   | 0.73 | 0.7195          | 0.0132
# Epoch 14/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 14:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7704          | 0.0036
# generator (test)       | 0.79 | 0.7913          | 0.0005
# discriminator (train)  | 0.77 | 0.7004          | 0.0711
# discriminator (test)   | 0.76 | 0.7431          | 0.0124
# Epoch 15/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 15:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7718          | 0.0027
# generator (test)       | 0.75 | 0.7465          | 0.0001
# discriminator (train)  | 0.76 | 0.7002          | 0.0621
# discriminator (test)   | 0.78 | 0.7634          | 0.0124
# Epoch 16/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 16:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7707          | 0.0031
# generator (test)       | 0.79 | 0.7853          | 0.0002
# discriminator (train)  | 0.76 | 0.7005          | 0.0611
# discriminator (test)   | 0.74 | 0.7292          | 0.0128
# Epoch 17/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 17:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7692          | 0.0033
# generator (test)       | 0.82 | 0.8195          | 0.0002
# discriminator (train)  | 0.76 | 0.6989          | 0.0579
# discriminator (test)   | 0.74 | 0.7320          | 0.0127
# Epoch 18/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 18:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7670          | 0.0031
# generator (test)       | 0.82 | 0.8213          | 0.0002
# discriminator (train)  | 0.75 | 0.6974          | 0.0566
# discriminator (test)   | 0.76 | 0.7441          | 0.0121
# Epoch 19/100
# 600/600 [==============================] - 100s 166ms/step
# Testing for epoch 19:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7708          | 0.0028
# generator (test)       | 0.77 | 0.7733          | 0.0004
# discriminator (train)  | 0.75 | 0.6976          | 0.0536
# discriminator (test)   | 0.73 | 0.7165          | 0.0119
# Epoch 20/100
# 600/600 [==============================] - 100s 166ms/step
# Testing for epoch 20:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7710          | 0.0020
# generator (test)       | 0.79 | 0.7897          | 0.0002
# discriminator (train)  | 0.75 | 0.6973          | 0.0513
# discriminator (test)   | 0.72 | 0.7040          | 0.0115
# Epoch 21/100
# 600/600 [==============================] - 99s 164ms/step
# Testing for epoch 21:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7671          | 0.0025
# generator (test)       | 0.77 | 0.7680          | 0.0004
# discriminator (train)  | 0.75 | 0.6971          | 0.0491
# discriminator (test)   | 0.73 | 0.7160          | 0.0123
# Epoch 22/100
# 600/600 [==============================] - 103s 171ms/step
# Testing for epoch 22:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7723          | 0.0021
# generator (test)       | 0.80 | 0.8018          | 0.0001
# discriminator (train)  | 0.75 | 0.6960          | 0.0503
# discriminator (test)   | 0.75 | 0.7367          | 0.0116
# Epoch 23/100
# 600/600 [==============================] - 100s 166ms/step
# Testing for epoch 23:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7744          | 0.0026
# generator (test)       | 0.77 | 0.7678          | 0.0001
# discriminator (train)  | 0.74 | 0.6957          | 0.0455
# discriminator (test)   | 0.72 | 0.7065          | 0.0112
# Epoch 24/100
# 600/600 [==============================] - 97s 162ms/step
# Testing for epoch 24:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7767          | 0.0020
# generator (test)       | 0.80 | 0.7963          | 0.0002
# discriminator (train)  | 0.74 | 0.6958          | 0.0442
# discriminator (test)   | 0.72 | 0.7131          | 0.0111
# Epoch 25/100
# 600/600 [==============================] - 95s 159ms/step
# Testing for epoch 25:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7743          | 0.0019
# generator (test)       | 0.79 | 0.7883          | 0.0004
# discriminator (train)  | 0.74 | 0.6958          | 0.0436
# discriminator (test)   | 0.73 | 0.7207          | 0.0112
# Epoch 26/100
# 600/600 [==============================] - 95s 158ms/step
# Testing for epoch 26:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7751          | 0.0017
# generator (test)       | 0.80 | 0.8039          | 0.0004
# discriminator (train)  | 0.74 | 0.6943          | 0.0432
# discriminator (test)   | 0.72 | 0.7035          | 0.0121
# Epoch 27/100
# 600/600 [==============================] - 100s 167ms/step
# Testing for epoch 27:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7725          | 0.0016
# generator (test)       | 0.80 | 0.7978          | 0.0004
# discriminator (train)  | 0.74 | 0.6948          | 0.0421
# discriminator (test)   | 0.72 | 0.7047          | 0.0118
# Epoch 28/100
# 600/600 [==============================] - 100s 167ms/step
# Testing for epoch 28:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7741          | 0.0017
# generator (test)       | 0.79 | 0.7894          | 0.0001
# discriminator (train)  | 0.73 | 0.6935          | 0.0395
# discriminator (test)   | 0.73 | 0.7232          | 0.0113
# Epoch 29/100
# 600/600 [==============================] - 102s 170ms/step
# Testing for epoch 29:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7727          | 0.0014
# generator (test)       | 0.77 | 0.7663          | 0.0002
# discriminator (train)  | 0.73 | 0.6950          | 0.0383
# discriminator (test)   | 0.72 | 0.7060          | 0.0114
# Epoch 30/100
# 600/600 [==============================] - 100s 166ms/step
# Testing for epoch 30:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7703          | 0.0012
# generator (test)       | 0.77 | 0.7682          | 0.0008
# discriminator (train)  | 0.73 | 0.6953          | 0.0373
# discriminator (test)   | 0.72 | 0.7095          | 0.0113
# Epoch 31/100
# 600/600 [==============================] - 98s 164ms/step
# Testing for epoch 31:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7715          | 0.0016
# generator (test)       | 0.79 | 0.7884          | 0.0001
# discriminator (train)  | 0.73 | 0.6952          | 0.0352
# discriminator (test)   | 0.72 | 0.7095          | 0.0114
# Epoch 32/100
# 600/600 [==============================] - 99s 165ms/step
# Testing for epoch 32:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7706          | 0.0013
# generator (test)       | 0.79 | 0.7934          | 0.0001
# discriminator (train)  | 0.73 | 0.6947          | 0.0343
# discriminator (test)   | 0.73 | 0.7226          | 0.0112
# Epoch 33/100
# 600/600 [==============================] - 96s 161ms/step
# Testing for epoch 33:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7723          | 0.0011
# generator (test)       | 0.80 | 0.7996          | 0.0001
# discriminator (train)  | 0.73 | 0.6948          | 0.0326
# discriminator (test)   | 0.72 | 0.7128          | 0.0110
# Epoch 34/100
# 600/600 [==============================] - 95s 159ms/step
# Testing for epoch 34:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7731          | 0.0013
# generator (test)       | 0.83 | 0.8288          | 0.0001
# discriminator (train)  | 0.73 | 0.6938          | 0.0330
# discriminator (test)   | 0.73 | 0.7168          | 0.0127
# Epoch 35/100
# 600/600 [==============================] - 95s 158ms/step
# Testing for epoch 35:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7727          | 0.0014
# generator (test)       | 0.80 | 0.7962          | 0.0000
# discriminator (train)  | 0.73 | 0.6925          | 0.0332
# discriminator (test)   | 0.72 | 0.7094          | 0.0104
# Epoch 36/100
# 600/600 [==============================] - 99s 165ms/step
# Testing for epoch 36:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.78 | 0.7738          | 0.0014
# generator (test)       | 0.82 | 0.8212          | 0.0001
# discriminator (train)  | 0.73 | 0.6923          | 0.0330
# discriminator (test)   | 0.71 | 0.7012          | 0.0102
# Epoch 37/100
# 600/600 [==============================] - 100s 166ms/step
# Testing for epoch 37:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7721          | 0.0011
# generator (test)       | 0.78 | 0.7811          | 0.0002
# discriminator (train)  | 0.72 | 0.6935          | 0.0306
# discriminator (test)   | 0.73 | 0.7199          | 0.0112
# Epoch 38/100
# 600/600 [==============================] - 98s 164ms/step
# Testing for epoch 38:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7691          | 0.0011
# generator (test)       | 0.79 | 0.7922          | 0.0001
# discriminator (train)  | 0.72 | 0.6937          | 0.0298
# discriminator (test)   | 0.72 | 0.7097          | 0.0110
# Epoch 39/100
# 600/600 [==============================] - 98s 163ms/step
# Testing for epoch 39:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7706          | 0.0013
# generator (test)       | 0.79 | 0.7884          | 0.0001
# discriminator (train)  | 0.73 | 0.6936          | 0.0316
# discriminator (test)   | 0.73 | 0.7191          | 0.0111
# Epoch 40/100
# 600/600 [==============================] - 95s 159ms/step
# Testing for epoch 40:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7699          | 0.0009
# generator (test)       | 0.83 | 0.8303          | 0.0000
# discriminator (train)  | 0.72 | 0.6933          | 0.0269
# discriminator (test)   | 0.73 | 0.7218          | 0.0111
# Epoch 41/100
# 600/600 [==============================] - 97s 161ms/step
# Testing for epoch 41:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7724          | 0.0012
# generator (test)       | 0.80 | 0.7980          | 0.0002
# discriminator (train)  | 0.72 | 0.6930          | 0.0286
# discriminator (test)   | 0.73 | 0.7140          | 0.0117
# Epoch 42/100
# 600/600 [==============================] - 98s 163ms/step
# Testing for epoch 42:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7707          | 0.0010
# generator (test)       | 0.81 | 0.8119          | 0.0001
# discriminator (train)  | 0.72 | 0.6934          | 0.0301
# discriminator (test)   | 0.74 | 0.7250          | 0.0110
# Epoch 43/100
# 600/600 [==============================] - 96s 160ms/step
# Testing for epoch 43:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7683          | 0.0010
# generator (test)       | 0.80 | 0.7961          | 0.0000
# discriminator (train)  | 0.72 | 0.6932          | 0.0277
# discriminator (test)   | 0.73 | 0.7134          | 0.0119
# Epoch 44/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 44:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7694          | 0.0009
# generator (test)       | 0.81 | 0.8065          | 0.0053
# discriminator (train)  | 0.72 | 0.6928          | 0.0282
# discriminator (test)   | 0.72 | 0.7091          | 0.0136
# Epoch 45/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 45:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7717          | 0.0010
# generator (test)       | 0.79 | 0.7886          | 0.0000
# discriminator (train)  | 0.72 | 0.6925          | 0.0265
# discriminator (test)   | 0.72 | 0.7121          | 0.0125
# Epoch 46/100
# 600/600 [==============================] - 93s 154ms/step
# Testing for epoch 46:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7717          | 0.0010
# generator (test)       | 0.81 | 0.8058          | 0.0000
# discriminator (train)  | 0.72 | 0.6928          | 0.0265
# discriminator (test)   | 0.72 | 0.7109          | 0.0123
# Epoch 47/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 47:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7685          | 0.0010
# generator (test)       | 0.79 | 0.7891          | 0.0001
# discriminator (train)  | 0.72 | 0.6934          | 0.0262
# discriminator (test)   | 0.71 | 0.6940          | 0.0115
# Epoch 48/100
# 600/600 [==============================] - 93s 154ms/step
# Testing for epoch 48:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7734          | 0.0010
# generator (test)       | 0.78 | 0.7803          | 0.0001
# discriminator (train)  | 0.72 | 0.6913          | 0.0259
# discriminator (test)   | 0.71 | 0.7025          | 0.0109
# Epoch 49/100
# 600/600 [==============================] - 93s 155ms/step
# Testing for epoch 49:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7724          | 0.0007
# generator (test)       | 0.79 | 0.7889          | 0.0001
# discriminator (train)  | 0.72 | 0.6923          | 0.0258
# discriminator (test)   | 0.72 | 0.7069          | 0.0110
# Epoch 50/100
# 600/600 [==============================] - 93s 154ms/step
# Testing for epoch 50:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7694          | 0.0007
# generator (test)       | 0.80 | 0.8037          | 0.0001
# discriminator (train)  | 0.72 | 0.6928          | 0.0251
# discriminator (test)   | 0.73 | 0.7144          | 0.0111
# Epoch 51/100
# 600/600 [==============================] - 93s 154ms/step
# Testing for epoch 51:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7698          | 0.0008
# generator (test)       | 0.79 | 0.7924          | 0.0000
# discriminator (train)  | 0.72 | 0.6929          | 0.0248
# discriminator (test)   | 0.72 | 0.7058          | 0.0111
# Epoch 52/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 52:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7699          | 0.0008
# generator (test)       | 0.81 | 0.8049          | 0.0002
# discriminator (train)  | 0.72 | 0.6927          | 0.0242
# discriminator (test)   | 0.72 | 0.7109          | 0.0119
# Epoch 53/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 53:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7687          | 0.0008
# generator (test)       | 0.81 | 0.8122          | 0.0000
# discriminator (train)  | 0.72 | 0.6923          | 0.0254
# discriminator (test)   | 0.71 | 0.6970          | 0.0098
# Epoch 54/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 54:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7711          | 0.0007
# generator (test)       | 0.81 | 0.8112          | 0.0000
# discriminator (train)  | 0.72 | 0.6919          | 0.0238
# discriminator (test)   | 0.72 | 0.7072          | 0.0125
# Epoch 55/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 55:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7698          | 0.0009
# generator (test)       | 0.80 | 0.7985          | 0.0000
# discriminator (train)  | 0.72 | 0.6920          | 0.0236
# discriminator (test)   | 0.71 | 0.7001          | 0.0111
# Epoch 56/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 56:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7710          | 0.0007
# generator (test)       | 0.82 | 0.8198          | 0.0000
# discriminator (train)  | 0.71 | 0.6917          | 0.0227
# discriminator (test)   | 0.71 | 0.6951          | 0.0106
# Epoch 57/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 57:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7700          | 0.0007
# generator (test)       | 0.82 | 0.8150          | 0.0000
# discriminator (train)  | 0.72 | 0.6919          | 0.0233
# discriminator (test)   | 0.72 | 0.7050          | 0.0104
# Epoch 58/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 58:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7698          | 0.0007
# generator (test)       | 0.80 | 0.8027          | 0.0000
# discriminator (train)  | 0.71 | 0.6914          | 0.0221
# discriminator (test)   | 0.71 | 0.7027          | 0.0114
# Epoch 59/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 59:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7680          | 0.0008
# generator (test)       | 0.83 | 0.8324          | 0.0006
# discriminator (train)  | 0.71 | 0.6921          | 0.0220
# discriminator (test)   | 0.71 | 0.7000          | 0.0117
# Epoch 60/100
# 600/600 [==============================] - 93s 154ms/step
# Testing for epoch 60:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7688          | 0.0008
# generator (test)       | 0.83 | 0.8347          | 0.0000
# discriminator (train)  | 0.71 | 0.6920          | 0.0212
# discriminator (test)   | 0.72 | 0.7113          | 0.0118
# Epoch 61/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 61:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7688          | 0.0008
# generator (test)       | 0.80 | 0.8004          | 0.0000
# discriminator (train)  | 0.71 | 0.6914          | 0.0194
# discriminator (test)   | 0.70 | 0.6932          | 0.0117
# Epoch 62/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 62:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7687          | 0.0006
# generator (test)       | 0.85 | 0.8533          | 0.0000
# discriminator (train)  | 0.71 | 0.6921          | 0.0210
# discriminator (test)   | 0.71 | 0.6983          | 0.0122
# Epoch 63/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 63:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7668          | 0.0006
# generator (test)       | 0.83 | 0.8337          | 0.0001
# discriminator (train)  | 0.71 | 0.6920          | 0.0187
# discriminator (test)   | 0.73 | 0.7137          | 0.0122
# Epoch 64/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 64:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7676          | 0.0008
# generator (test)       | 0.82 | 0.8208          | 0.0001
# discriminator (train)  | 0.71 | 0.6923          | 0.0200
# discriminator (test)   | 0.72 | 0.7106          | 0.0118
# Epoch 65/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 65:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7661          | 0.0006
# generator (test)       | 0.84 | 0.8401          | 0.0000
# discriminator (train)  | 0.71 | 0.6923          | 0.0196
# discriminator (test)   | 0.71 | 0.7007          | 0.0102
# Epoch 66/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 66:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7678          | 0.0008
# generator (test)       | 0.83 | 0.8333          | 0.0000
# discriminator (train)  | 0.71 | 0.6924          | 0.0201
# discriminator (test)   | 0.70 | 0.6916          | 0.0111
# Epoch 67/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 67:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7695          | 0.0006
# generator (test)       | 0.82 | 0.8201          | 0.0000
# discriminator (train)  | 0.71 | 0.6913          | 0.0196
# discriminator (test)   | 0.72 | 0.7068          | 0.0119
# Epoch 68/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 68:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7655          | 0.0006
# generator (test)       | 0.84 | 0.8386          | 0.0000
# discriminator (train)  | 0.71 | 0.6925          | 0.0220
# discriminator (test)   | 0.72 | 0.7058          | 0.0121
# Epoch 69/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 69:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7658          | 0.0006
# generator (test)       | 0.84 | 0.8425          | 0.0003
# discriminator (train)  | 0.71 | 0.6925          | 0.0194
# discriminator (test)   | 0.72 | 0.7058          | 0.0112
# Epoch 70/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 70:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7647          | 0.0006
# generator (test)       | 0.83 | 0.8308          | 0.0002
# discriminator (train)  | 0.71 | 0.6926          | 0.0186
# discriminator (test)   | 0.71 | 0.6975          | 0.0111
# Epoch 71/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 71:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7643          | 0.0006
# generator (test)       | 0.81 | 0.8082          | 0.0000
# discriminator (train)  | 0.71 | 0.6924          | 0.0200
# discriminator (test)   | 0.71 | 0.6974          | 0.0115
# Epoch 72/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 72:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7653          | 0.0007
# generator (test)       | 0.82 | 0.8197          | 0.0004
# discriminator (train)  | 0.71 | 0.6932          | 0.0180
# discriminator (test)   | 0.70 | 0.6895          | 0.0118
# Epoch 73/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 73:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7647          | 0.0005
# generator (test)       | 0.84 | 0.8363          | 0.0000
# discriminator (train)  | 0.71 | 0.6928          | 0.0196
# discriminator (test)   | 0.72 | 0.7075          | 0.0118
# Epoch 74/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 74:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7645          | 0.0007
# generator (test)       | 0.86 | 0.8602          | 0.0000
# discriminator (train)  | 0.71 | 0.6932          | 0.0186
# discriminator (test)   | 0.72 | 0.7070          | 0.0116
# Epoch 75/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 75:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7656          | 0.0005
# generator (test)       | 0.84 | 0.8365          | 0.0000
# discriminator (train)  | 0.71 | 0.6926          | 0.0178
# discriminator (test)   | 0.71 | 0.6964          | 0.0101
# Epoch 76/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 76:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7663          | 0.0006
# generator (test)       | 0.85 | 0.8498          | 0.0002
# discriminator (train)  | 0.71 | 0.6922          | 0.0187
# discriminator (test)   | 0.71 | 0.6940          | 0.0114
# Epoch 77/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 77:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7660          | 0.0007
# generator (test)       | 0.82 | 0.8155          | 0.0000
# discriminator (train)  | 0.71 | 0.6924          | 0.0176
# discriminator (test)   | 0.70 | 0.6913          | 0.0111
# Epoch 78/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 78:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.77 | 0.7647          | 0.0005
# generator (test)       | 0.83 | 0.8307          | 0.0000
# discriminator (train)  | 0.71 | 0.6923          | 0.0173
# discriminator (test)   | 0.70 | 0.6892          | 0.0117
# Epoch 79/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 79:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7634          | 0.0005
# generator (test)       | 0.82 | 0.8227          | 0.0002
# discriminator (train)  | 0.71 | 0.6928          | 0.0187
# discriminator (test)   | 0.71 | 0.6960          | 0.0107
# Epoch 80/100
# 600/600 [==============================] - 92s 154ms/step
# Testing for epoch 80:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7629          | 0.0005
# generator (test)       | 0.82 | 0.8178          | 0.0001
# discriminator (train)  | 0.71 | 0.6934          | 0.0151
# discriminator (test)   | 0.71 | 0.6974          | 0.0112
# Epoch 81/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 81:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7628          | 0.0006
# generator (test)       | 0.86 | 0.8609          | 0.0001
# discriminator (train)  | 0.71 | 0.6929          | 0.0163
# discriminator (test)   | 0.72 | 0.7094          | 0.0119
# Epoch 82/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 82:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7636          | 0.0006
# generator (test)       | 0.79 | 0.7888          | 0.0001
# discriminator (train)  | 0.71 | 0.6932          | 0.0185
# discriminator (test)   | 0.71 | 0.6934          | 0.0124
# Epoch 83/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 83:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7627          | 0.0008
# generator (test)       | 0.80 | 0.7946          | 0.0004
# discriminator (train)  | 0.71 | 0.6939          | 0.0153
# discriminator (test)   | 0.70 | 0.6897          | 0.0111
# Epoch 84/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 84:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7629          | 0.0006
# generator (test)       | 0.82 | 0.8161          | 0.0000
# discriminator (train)  | 0.71 | 0.6929          | 0.0166
# discriminator (test)   | 0.70 | 0.6926          | 0.0116
# Epoch 85/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 85:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7633          | 0.0005
# generator (test)       | 0.83 | 0.8335          | 0.0000
# discriminator (train)  | 0.71 | 0.6925          | 0.0162
# discriminator (test)   | 0.70 | 0.6903          | 0.0113
# Epoch 86/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 86:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7628          | 0.0005
# generator (test)       | 0.82 | 0.8192          | 0.0000
# discriminator (train)  | 0.71 | 0.6930          | 0.0167
# discriminator (test)   | 0.71 | 0.6982          | 0.0112
# Epoch 87/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 87:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7625          | 0.0006
# generator (test)       | 0.77 | 0.7730          | 0.0000
# discriminator (train)  | 0.71 | 0.6926          | 0.0168
# discriminator (test)   | 0.72 | 0.7094          | 0.0114
# Epoch 88/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 88:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7614          | 0.0004
# generator (test)       | 0.78 | 0.7798          | 0.0000
# discriminator (train)  | 0.71 | 0.6934          | 0.0168
# discriminator (test)   | 0.72 | 0.7054          | 0.0119
# Epoch 89/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 89:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7623          | 0.0006
# generator (test)       | 0.81 | 0.8076          | 0.0002
# discriminator (train)  | 0.71 | 0.6926          | 0.0150
# discriminator (test)   | 0.71 | 0.7011          | 0.0111
# Epoch 90/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 90:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7611          | 0.0007
# generator (test)       | 0.81 | 0.8084          | 0.0001
# discriminator (train)  | 0.71 | 0.6925          | 0.0148
# discriminator (test)   | 0.71 | 0.6973          | 0.0113
# Epoch 91/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 91:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7627          | 0.0005
# generator (test)       | 0.80 | 0.7964          | 0.0000
# discriminator (train)  | 0.71 | 0.6928          | 0.0165
# discriminator (test)   | 0.71 | 0.7022          | 0.0122
# Epoch 92/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 92:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7618          | 0.0004
# generator (test)       | 0.78 | 0.7795          | 0.0001
# discriminator (train)  | 0.71 | 0.6926          | 0.0150
# discriminator (test)   | 0.72 | 0.7127          | 0.0112
# Epoch 93/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 93:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7619          | 0.0005
# generator (test)       | 0.81 | 0.8053          | 0.0000
# discriminator (train)  | 0.71 | 0.6931          | 0.0148
# discriminator (test)   | 0.72 | 0.7099          | 0.0113
# Epoch 94/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 94:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7638          | 0.0005
# generator (test)       | 0.80 | 0.7964          | 0.0000
# discriminator (train)  | 0.71 | 0.6922          | 0.0159
# discriminator (test)   | 0.71 | 0.7016          | 0.0115
# Epoch 95/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 95:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7609          | 0.0004
# generator (test)       | 0.80 | 0.7967          | 0.0000
# discriminator (train)  | 0.71 | 0.6931          | 0.0155
# discriminator (test)   | 0.72 | 0.7080          | 0.0111
# Epoch 96/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 96:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7610          | 0.0004
# generator (test)       | 0.81 | 0.8125          | 0.0000
# discriminator (train)  | 0.71 | 0.6928          | 0.0168
# discriminator (test)   | 0.72 | 0.7115          | 0.0126
# Epoch 97/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 97:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7617          | 0.0005
# generator (test)       | 0.77 | 0.7724          | 0.0001
# discriminator (train)  | 0.71 | 0.6924          | 0.0154
# discriminator (test)   | 0.71 | 0.6994          | 0.0108
# Epoch 98/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 98:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7604          | 0.0007
# generator (test)       | 0.80 | 0.8018          | 0.0000
# discriminator (train)  | 0.71 | 0.6930          | 0.0153
# discriminator (test)   | 0.73 | 0.7178          | 0.0101
# Epoch 99/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 99:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7625          | 0.0006
# generator (test)       | 0.82 | 0.8229          | 0.0000
# discriminator (train)  | 0.71 | 0.6920          | 0.0142
# discriminator (test)   | 0.72 | 0.7098          | 0.0114
# Epoch 100/100
# 600/600 [==============================] - 92s 153ms/step
# Testing for epoch 100:
# component              | loss | generation_loss | auxiliary_loss
# -----------------------------------------------------------------
# generator (train)      | 0.76 | 0.7638          | 0.0005
# generator (test)       | 0.81 | 0.8100          | 0.0002
# discriminator (train)  | 0.71 | 0.6923          | 0.0132
# discriminator (test)   | 0.72 | 0.7055          | 0.0102
